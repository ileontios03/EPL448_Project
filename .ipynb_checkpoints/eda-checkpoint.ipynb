# %%
# Import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load dataset
df = pd.read_csv('alzheimers_prediction_dataset.csv')

# %% [markdown]
# # Exploratory Data Analysis
# Get familiar with our dataset

# %%
# Print 5 first observations 
df.head()
# Out:
#         Country  Age  Gender  Education Level   BMI Physical Activity Level  \
# 0         Spain   90    Male                1  33.0                  Medium
# 1     Argentina   72    Male                7  29.9                  Medium
# 2  South Africa   86  Female               19  22.9                    High
# 3         China   53    Male               17  31.2                     Low
# 4        Sweden   58  Female                3  30.0                    High
#
#   Smoking Status Alcohol Consumption Diabetes Hypertension  ...  \
# 0          Never        Occasionally       No           No  ...
# 1         Former               Never       No           No  ...
# 2        Current        Occasionally       No          Yes  ...
# 3          Never           Regularly      Yes           No  ...
# 4         Former               Never      Yes           No  ...
#
#   Dietary Habits Air Pollution Exposure  Employment Status Marital Status  \
# ...

# %%
# print column types
df.dtypes
# Out:
# Country                                  object
# Age                                       int64
# Gender                                   object
# Education Level                           int64
# BMI                                     float64
# Physical Activity Level                  object
# Smoking Status                           object
# Alcohol Consumption                      object
# Diabetes                                 object
# Hypertension                             object
# Cholesterol Level                        object
# Family History of Alzheimer’s            object
# Cognitive Test Score                      int64
# Depression Level                         object
# Sleep Quality                            object
# Dietary Habits                           object
# Air Pollution Exposure                   object
# Employment Status                        object
# Marital Status                           object
# Genetic Risk Factor (APOE-ε4 allele)     object
# ...

# %% [markdown]
# #### Data Types
# As most of our columns are strings(object) we will need to encode them in the next steps to numbers.
# Also, there are no unnecessary columns that we can drop (such as Name, PatientID, etc...)

# %%
# Missing values
missing_values = df.isnull().sum()
print("Missing Values per Column:")
missing_values
# Out:
# Missing Values per Column:
# Country                                 0
# Age                                     0
# Gender                                  0
# Education Level                         0
# BMI                                     0
# Physical Activity Level                 0
# Smoking Status                          0
# Alcohol Consumption                     0
# Diabetes                                0
# Hypertension                            0
# Cholesterol Level                       0
# Family History of Alzheimer’s           0
# Cognitive Test Score                    0
# Depression Level                        0
# Sleep Quality                           0
# Dietary Habits                          0
# Air Pollution Exposure                  0
# Employment Status                       0
# Marital Status                          0
# Genetic Risk Factor (APOE-ε4 allele)    0
# Social Engagement Level                 0
# Income Level                            0
# ...

# %% [markdown]
# #### Missing Values
# As we can see we have no missing in our dataset which makes our work easier

# %%
# Summary statistics for numerical features
print("Summary Statistics:")
df.describe()
# Out:
# Summary Statistics:
#                 Age  Education Level           BMI  Cognitive Test Score
# count  74283.000000     74283.000000  74283.000000          74283.000000
# mean      71.964703         9.487514     26.780639             64.654241
# std       12.980748         5.757020      4.764679             20.153247
# min       50.000000         0.000000     18.500000             30.000000
# 25%       61.000000         4.000000     22.700000             47.000000
# 50%       72.000000         9.000000     26.800000             65.000000
# 75%       83.000000        14.000000     30.900000             82.000000
# max       94.000000        19.000000     35.000000             99.000000

# %% [markdown]
# #### Check if the dataset is balanced
# Plotting the distribution of the patient's diagnosis (Yes/No) to see if our dataset is balanced

# %%
# Count plot for Alzheimer’s Diagnosis
sns.countplot(data=df, x='Alzheimer’s Diagnosis')
plt.title('Distribution of Alzheimer’s Diagnosis')
plt.show()

# Check the value counts
df['Alzheimer’s Diagnosis'].value_counts(normalize=True)
# Out:
# Alzheimer’s Diagnosis
# No     0.586541
# Yes    0.413459
# Name: proportion, dtype: float64

# %% [markdown]
# Since the proportion is very close to 50/50 we can say that our dataset is balanced.

# %% [markdown]
# #### Distrbution of Age vs diagnosis
# We can see that for older ages there is a higher chance of alzheimer's so we can say that age is one of the most important features

# %%
# Plot for 'No' (not diagnosed)
plt.figure(figsize=(8, 5))
sns.histplot(
    data=df[df['Alzheimer’s Diagnosis'] == 'No'],
    x='Age',
    bins=30,
    kde=True,
    color='mediumseagreen',
    edgecolor='black'
)
plt.title("Age Distribution - Not Diagnosed with Alzheimer's")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
# Out:
# C:\Users\Leontios\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Plot for 'Yes' (diagnosed)
plt.figure(figsize=(8, 5))
sns.histplot(
    data=df[df['Alzheimer’s Diagnosis'] == 'Yes'],
    x='Age',
    bins=30,
    kde=True,
    color='salmon',
    edgecolor='black'
)
plt.title("Age Distribution - Diagnosed with Alzheimer's")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# #### Gender vs Alzheimer's Diagnosis
# We can say that the gender and the diagnosis are not correlated at all

# %%
# Plot diagnosis per gender 
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Gender', hue='Alzheimer’s Diagnosis', palette='Set2')
plt.title('Gender vs Alzheimer’s Diagnosis')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Alzheimer’s Diagnosis')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))  # Increase width for many countries
sns.countplot(data=df, x='Country', hue='Alzheimer’s Diagnosis', palette='Set2')
plt.title('Alzheimer’s Diagnosis by Country')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate for readability
plt.legend(title='Diagnosis')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Genetic Risk Factor (APOE-ε4 allele)', hue='Alzheimer’s Diagnosis', palette='coolwarm')
plt.title('Alzheimer’s Diagnosis by Genetic Risk Factor')
plt.xlabel('APOE-ε4 allele Present?')
plt.ylabel('Count')
plt.legend(title='Diagnosis')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Education Level', hue='Alzheimer’s Diagnosis', palette='viridis')
plt.title('Alzheimer’s Diagnosis by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate for readability if needed
plt.legend(title='Diagnosis')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Family History of Alzheimer’s', hue='Alzheimer’s Diagnosis', palette='coolwarm')
plt.title('Alzheimer’s Diagnosis by Family History of Alzheimer’s')
plt.xlabel('Family History of Alzheimer’s')
plt.ylabel('Count')
plt.legend(title='Diagnosis')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Stress Levels', hue='Alzheimer’s Diagnosis', palette='coolwarm')
plt.title('Alzheimer’s Diagnosis by Stress Levels')
plt.xlabel('Stress Levels')
plt.ylabel('Count')
plt.legend(title='Diagnosis')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Smoking Status', hue='Alzheimer’s Diagnosis', palette='coolwarm')
plt.title('Alzheimer’s Diagnosis by Smoking Status')
plt.xlabel('Smoking Status')
plt.ylabel('Count')
plt.legend(title='Diagnosis')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Alzheimer’s Diagnosis', y='Cognitive Test Score', palette='coolwarm')
plt.title('Cognitive Test Score by Alzheimer’s Diagnosis')
plt.xlabel('Alzheimer’s Diagnosis')
plt.ylabel('Cognitive Test Score')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Alcohol Consumption', hue='Alzheimer’s Diagnosis', palette='coolwarm')
plt.title('Alzheimer’s Diagnosis by Alcohol Consumption')
plt.xlabel('Alcohol Consumption')
plt.ylabel('Count')
plt.legend(title='Diagnosis')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Physical Activity Level', hue='Alzheimer’s Diagnosis', palette='coolwarm')
plt.title('Alzheimer’s Diagnosis by Physical Activity Level')
plt.xlabel('Physical Activity Level')
plt.ylabel('Count')
plt.legend(title='Diagnosis')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Social Engagement Level', hue='Alzheimer’s Diagnosis', palette='coolwarm')
plt.title('Alzheimer’s Diagnosis by Social Engagement Level')
plt.xlabel('Social Engagement Level')
plt.ylabel('Count')
plt.legend(title='Diagnosis')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Marital Status', hue='Alzheimer’s Diagnosis', palette='coolwarm')
plt.title('Alzheimer’s Diagnosis by Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.legend(title='Diagnosis')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Diabetes', hue='Alzheimer’s Diagnosis', palette='coolwarm')
plt.title('Alzheimer’s Diagnosis by Diabetes Status')
plt.xlabel('Diabetes Status')
plt.ylabel('Count')
plt.legend(title='Diagnosis')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Hypertension', hue='Alzheimer’s Diagnosis', palette='coolwarm')
plt.title('Alzheimer’s Diagnosis by Hypertension Status')
plt.xlabel('Hypertension Status')
plt.ylabel('Count')
plt.legend(title='Diagnosis')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Urban vs Rural Living', hue='Alzheimer’s Diagnosis', palette='coolwarm')
plt.title('Alzheimer’s Diagnosis by Urban vs Rural Living')
plt.xlabel('Urban vs Rural Living')
plt.ylabel('Count')
plt.legend(title='Diagnosis')
plt.tight_layout()
plt.show()
